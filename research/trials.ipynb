# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from scipy.stats import shapiro
import warnings
import os
from pathlib import Path
from ensure import ensure_annotations
from MLProject import logger
import numpy as np

# %%
if Path(os.getcwd()) != Path('d:/Code Workspace/Personal Project/Personal Project - End to End Loan Status Classification'):
    os.chdir('../')
# %pwd
# Out:
# 'd:\\Code Workspace\\Personal Project\\Personal Project - End to End Loan Status Classification'

# %%
d = {
    "a": 1,
    "b": 2,
    "c": 3
}

# %%
d["a"]
# Out:
# 1

# %%
from box import ConfigBox

# %%
d2 =ConfigBox(
    d
)

# %%
d2.a
# Out:
# 1

# %%
from MLProject.utils.common import load_bin, read_yaml

le = load_bin(Path('artifacts\data_transformation\label_encoders.bin'))
sc = load_bin(Path('artifacts\data_transformation\scaler.bin'))
model = load_bin(Path('artifacts\model_trainer\model.joblib'))
model
# Out:
# | 2024-01-24 18:45:47,340 | INFO | common | binary file loaded from: artifacts\data_transformation\label_encoders.bin |
# | 2024-01-24 18:45:47,340 | INFO | common | binary file loaded from: artifacts\data_transformation\scaler.bin |
# | 2024-01-24 18:45:47,347 | INFO | common | binary file loaded from: artifacts\model_trainer\model.joblib |
# SVC(C=1, degree=1, kernel='poly', random_state=42)

# %%
df = pd.read_csv("D:\Code Workspace\Personal Project\Personal Project - End to End Loan Status Classification\\artifacts\data_ingestion\credit_train.csv")

# %%
df[df['Loan Status'] == 'Charged Off']
# Out:
#                                     Loan ID  \
# 5      89d8cb0c-e5c2-4f54-b056-48a645c543dd
# 7      db0dc6e1-77ee-4826-acca-772f9039e1c7
# 16     c9a16a9d-8801-4430-b445-dbf9cf845e31
# 20     150ebbad-ebed-441e-b70d-2f350ad7dca6
# 22     c7e2b784-016b-4fc4-8fde-623f09126557
# ...                                     ...
# 99963  7912d91b-f51a-424d-9087-94355b47a8fc
# 99975  922f7953-b9ee-4957-a317-6de753509856
# 99981  21121eb3-4590-4dad-8f90-b78cb73b647b
# 99988  125a4df1-c538-4b1e-b37f-b515a2ce370c
# 99989  2649e526-3866-4555-91a3-9bd5d26dcba2
#
#                                 Customer ID  Loan Status  Current Loan Amount  \
# 5      4ffe99d3-7f2a-44db-afc1-40943f1f9750  Charged Off             206602.0
# 7      018973c9-e316-4956-b363-67e134fb0931  Charged Off             648714.0
# 16     abb4c446-08ea-49ff-aeb8-5e1e9da673e7  Charged Off             653004.0
# 20     40f729c9-54c7-4768-9fb5-2fa41d074c48  Charged Off             317108.0
# ...

# %%
df_clean = df.drop("Loan_Status", axis=1)

# %%
df_clean.head(1)
# Out:
#    Current_Loan_Amount  Term  Credit_Score  Annual_Income  \
# 0            -0.569126     1          -1.0       1.313914
#
#    Years_in_current_job  Home_Ownership  Purpose  Monthly_Debt  \
# 0                     2               3        3     -0.059894
#
#    Years_of_Credit_History  Number_of_Open_Accounts  \
# 0                -0.592593                 0.333333
#
#    Number_of_Credit_Problems  Current_Credit_Balance  Maximum_Open_Credit  \
# 0                        1.0               -0.528899            -0.287109
#
#    Bankruptcies  Tax_Liens
# 0           0.0        1.0

# %%
model.predict(df_clean.head(1))
# Out:
# array([1], dtype=int64)

# %%
data = {
  "Current_Loan_Amount": 7280000,
  "Term": "Long Term",
  "Credit_Score": 600,
  "Annual_Income": 60000,
  "Years_in_current_job": "3 years",
  "Home_Ownership": "Rent",
  "Purpose": "Debt Consolidation",
  "Monthly_Debt": 20806,
  "Years_of_Credit_History": 60,
  "Months_since_last_delinquent": 10,
  "Number_of_Open_Accounts": 10,
  "Number_of_Credit_Problems": 30,
  "Current_Credit_Balance": 30000,
  "Maximum_Open_Credit": 60000,
  "Bankruptcies": 0,
  "Tax_Liens": 0
}

# %%
col = read_yaml(Path("artifacts\data_transformation\column_info.yaml"))
# Out:
# | 2024-01-24 19:30:02,558 | INFO | common | yaml file: artifacts\data_transformation\column_info.yaml loaded successfully |

# %%
# Convert the dictionary to a pandas DataFrame
df = pd.DataFrame([data])

df
# Out:
#    Current_Loan_Amount       Term  Credit_Score  Annual_Income  \
# 0              7280000  Long Term           600          60000
#
#   Years_in_current_job Home_Ownership             Purpose  Monthly_Debt  \
# 0              3 years           Rent  Debt Consolidation         20806
#
#    Years_of_Credit_History  Months_since_last_delinquent  \
# 0                       60                            10
#
#    Number_of_Open_Accounts  Number_of_Credit_Problems  Current_Credit_Balance  \
# 0                       10                         30                   30000
#
#    Maximum_Open_Credit  Bankruptcies  Tax_Liens
# 0                60000             0          0

# %%
# Months_since_last_delinquent

# %%
def remove_unused_columns(data: pd.DataFrame) -> pd.DataFrame:
    if os.path.exists("artifacts\data_transformation\column_info.yaml"):
        col_info = read_yaml(Path("artifacts\data_transformation\column_info.yaml"))
        return data.drop(col_info.drop_feature_columns, axis= 1)

# %%
df.shape
# Out:
# (1, 16)

# %%
df_clean = remove_unused_columns(df)
# Out:
# | 2024-01-24 19:30:07,823 | INFO | common | yaml file: artifacts\data_transformation\column_info.yaml loaded successfully |

# %%
df_clean.shape
# Out:
# (1, 15)

# %%
data.get('Term')
# Out:
# 'Long Term'

# %%
sc
# Out:
# RobustScaler()

# %%
df[list(col.numeric_features)]
# Out:
#    Current_Loan_Amount  Credit_Score  Annual_Income  Monthly_Debt  \
# 0              7280000           600          60000         20806
#
#    Years_of_Credit_History  Number_of_Open_Accounts  \
# 0                       60                       10
#
#    Number_of_Credit_Problems  Current_Credit_Balance  Maximum_Open_Credit  \
# 0                         30                   30000                60000
#
#    Bankruptcies  Tax_Liens
# 0             0          0

# %%
def get_inference_transfomation(data: pd.DataFrame) -> pd.DataFrame:
    le = load_bin(Path('artifacts\data_transformation\label_encoders.bin'))
    sc = load_bin(Path('artifacts\data_transformation\scaler.bin'))
    col_info = read_yaml(Path("artifacts\data_transformation\column_info.yaml"))

    for column in le.keys():
        try:
            data[column] = le[column].transform(data[column])
        except:
            pass
    col = col_info.numeric_features
    
    data[list(col)] = sc.transform(data[list(col)])
    
    return data
        
    
        


# def get_test_transormation(self):
#         data = pd.read_csv(self.test_path)
#         le = load_bin(self.le_path)
#         sc = load_bin(self.sc_path)

#         logger.info(f"Starting transforming test data")
#         data[self.numeric_features] = sc.transform(data[self.numeric_features])
#         for column in le.keys():
#             data[column] = le[column].transform(data[column])
        
#         logger.info(f"Transforming test data completed")
#         self._save_df(data, self.test_path)

# %%
test = get_inference_transfomation(df_clean)
# Out:
# | 2024-01-24 19:30:12,397 | INFO | common | binary file loaded from: artifacts\data_transformation\label_encoders.bin |
# | 2024-01-24 19:30:12,397 | INFO | common | binary file loaded from: artifacts\data_transformation\scaler.bin |
# | 2024-01-24 19:30:12,401 | INFO | common | yaml file: artifacts\data_transformation\column_info.yaml loaded successfully |

# %%
le['Loan_Status'].inverse_transform(model.predict(test))
# Out:
# array(['Fully Paid'], dtype=object)

# %%
model.predict(test)
# Out:
# array([1], dtype=int64)

# %%
data= pd.read_csv("artifacts\data_transformation\\train.csv")

# %%
X = data.drop("Loan_Status", axis=1)
y = data["Loan_Status"]

# %%
print(y[y == 0])
# Out:
# 3        0
# 5        0
# 15       0
# 16       0
# 24       0
#         ..
# 71649    0
# 71652    0
# 71663    0
# 71671    0
# 71672    0
# Name: Loan_Status, Length: 15969, dtype: int64

# %%
result = model.predict(X)

# %%
from sklearn.metrics import classification_report

print(classification_report(y, result))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.20      0.34     15969
#            1       0.81      1.00      0.90     55710
#
#     accuracy                           0.82     71679
#    macro avg       0.91      0.60      0.62     71679
# weighted avg       0.86      0.82      0.77     71679
